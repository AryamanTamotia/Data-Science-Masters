# %% [markdown]
# # 19 February 2023

# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Q1

# %% [markdown]
# Flask is a popular Python web framework used for building web applications. It is a lightweight and flexible framework that allows developers to quickly develop web applications with ease.
#
# Advantages of Flask Framework:
#
# 1. Lightweight and Flexible: Flask is a lightweight and flexible framework that allows developers to choose the tools and libraries that they want to use.
#
# 2. Easy to Learn: Flask is easy to learn and has a simple and intuitive API. This makes it an ideal choice for beginners who are just starting with web development.
#
# 3. Built-in Development Server: Flask comes with a built-in development server that makes it easy to test and debug your web application.
#
# 4. Extensible: Flask is highly extensible and has a large number of third-party extensions available. These extensions make it easy to add new features and functionality to your web application.
#
# 5. Great Community Support: Flask has a large and active community of developers who are constantly working on new projects and improving the framework.

# %% [markdown]
# ## Q2

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "Hello World!!"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:11d1dcc8-4aba-4ce7-b067-392e4798fa1c.png)

# %% [markdown]
# ## Q3

# %% [markdown]
# In Flask, app routing refers to defining the different routes (URLs) that an application can handle. It is the process of mapping a URL to a Python function. In Flask, the @app.route decorator is used to define routes.
#
# We use app routes to define the different URLs that our application can handle. By defining routes, we can make our application more organized and easier to maintain. It also makes it easier for users to access different parts of the application.

# %% [markdown]
# ## Q4

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world1():
    return """Company Name: ABC Corporation
    Location: India
    Contact Detail:999-999-999"""

@app.route("/welcome")
def hello_world2():
    return "Welcome to ABC Corporation"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:d18ba650-3e77-4bbb-bfac-4dfa863f3787.png)

# %% [markdown]
# ![image.png](attachment:154d235d-7a5a-4d0d-aa92-620343e75f07.png)

# %% [markdown]
# REST is an architectural style that uses HTTP requests to retrieve or modify data, typically using JSON or XML as the data format. It is based on the principles of stateless client-server architecture and can be used over a variety of transport protocols, including HTTP, HTTPS, SMTP, and more. REST APIs are lightweight, scalable, and easy to build and maintain.
#
# SOAP, on the other hand, is an XML-based messaging protocol for exchanging data between applications over a network. It is a protocol that is designed to communicate between two systems over the internet, typically using XML as the data format. SOAP APIs are more complex than REST APIs, but they offer more advanced features such as security and transaction support.
#
# One of the main shortcomings of SOAP is its complexity. SOAP is a highly structured and standardized protocol, which can make it difficult to work with and implement. It also requires more processing power and bandwidth, which can slow down performance. Additionally, SOAP is often seen as less flexible than REST because it relies on XML as the data format, which can be more difficult to work with than JSON.

# %% [markdown]
# ## Q5

# %% [markdown]
# In Flask, url_for() function is used for url building. It takes the endpoint name as argument and returns the URL for that endpoint.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def home():
    return 'Welcome to the home page!'

@app.route('/user/<username>')
def profile(username):
    return f'Welcome to the profile page, {username}!'

@app.route('/product/<int:product_id>')
def product(product_id):
    return f'Product ID: {product_id}'

with app.test_request_context():
    print(url_for('home'))
    print(url_for('profile', username='John'))
    print(url_for('product', product_id=10))

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
# /
# /user/John
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.11:5000
# Press CTRL+C to quit
